# %%
import socket

client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client_socket.connect(('localhost', 65432))

# Send name and student ID
message = "Name: Suleman Awan, Student ID: 33791096"
client_socket.sendall(message.encode())

# Receive echo
response = client_socket.recv(1024)
print(f"Server response: {response.decode()}")

client_socket.close()
# Out:
# Server response: Name: Suleman Awan, Student ID: 33791096

# %%
import socket

client_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
server_address = ('localhost', 65432)

message = "Name: Suleman Awan, Student ID: 33791096"
client_socket.sendto(message.encode(), server_address)

response, _ = client_socket.recvfrom(1024)
print(f"Server response: {response.decode()}")

client_socket.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[2], line 9
#       6 message = "Name: Suleman Awan, Student ID: 33791096"
#       7 client_socket.sendto(message.encode(), server_address)
# ----> 9 response, _ = client_socket.recvfrom(1024)
#      10 print(f"Server response: {response.decode()}")
#      12 client_socket.close()
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
