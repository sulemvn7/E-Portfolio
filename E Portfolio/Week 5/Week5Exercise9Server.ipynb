# %%
import socket

HOST = '127.0.0.1'
PORT = 65433

server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server.bind((HOST, PORT))
server.listen(1)

print("🌤️ Weather TCP Server running... Waiting for data...")

conn, addr = server.accept()
print(f"🔌 Connected by {addr}")

data = conn.recv(1024)

if data:
    print("📩 Received weather data:")
    print(data.decode())

conn.close()
server.close()
print("🔴 Server closed.")
# Out:
# 🌤️ Weather TCP Server running... Waiting for data...
# 🔌 Connected by ('127.0.0.1', 23665)
# 📩 Received weather data:
# Current Temperature: 13.5°C | Wind Speed: 17.6 km/h
# 🔴 Server closed.
