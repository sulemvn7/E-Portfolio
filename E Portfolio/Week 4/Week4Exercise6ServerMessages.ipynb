# %%
import socket

server_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
server_socket.bind(('localhost', 65433))
print("🟢 Weather server started, waiting for data...")

data, address = server_socket.recvfrom(1024)
print(f"📩 Received weather data from {address}: {data.decode()}")
# Out:
# 🟢 Weather server started, waiting for data...
# 📩 Received weather data from ('127.0.0.1', 53172): University: 13.1°C, British Library: 14.5°C
