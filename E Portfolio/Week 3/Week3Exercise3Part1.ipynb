# %%
import subprocess

def tracert(domain):
    try:
        print(f"🗺️ Tracking route to {domain}...")
        print("⏳ This takes 1-2 minutes - your data is globehopping!")
        print("=" * 60)

        result = subprocess.run(
            ["tracert", domain], 
            capture_output=True,
            text=True
        )

        print(result.stdout)

        print("=" * 60)
        print("✅ Journey complete! Check out that route!")

    except FileNotFoundError:
        print("❌ tracert not found. Are you on Windows?")
        print("💡 Mac/Linux users: try 'traceroute' instead!")

    except Exception as e:
        print(f"❌ Something went wrong: {e}")


print("🗺️ NETWORK PATHFINDER 🗺️")
domain = input("Enter website or IP to track: ")
tracert(domain)
# Out:
# 🗺️ NETWORK PATHFINDER 🗺️
# Enter website or IP to track:  google.com
# 🗺️ Tracking route to google.com...
# ⏳ This takes 1-2 minutes - your data is globehopping!
# ...
#
# Tracing route to google.com [2a00:1450:4009:c08::8b]
# over a maximum of 30 hops:
#
#   1     1 ms     1 ms     1 ms  2a02:c7c:5168:9b00::1
#   2     *        *        *     Request timed out.
#   3    14 ms    10 ms     5 ms  2001:4860:1:1::679
#   4     6 ms     5 ms     4 ms  2001:4860:1:1::678
#   5     6 ms     4 ms     5 ms  2a00:1450:8204:140::1
#   6     8 ms     6 ms     5 ms  2001:4860:0:1::54c8
#   7     7 ms     5 ms     6 ms  2001:4860:0:1::33c8
#   8     *        *        *     Request timed out.
#   9     *        *        *     Request timed out.
#  10     *        *        *     Request timed out.
#  11     *        *        *     Request timed out.
#  12     *        *        *     Request timed out.
#  13     *        *        *     Request timed out.
# ...
